# %%
import mysql.connector as connection
import pandas as pd

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB 330.3 kB/s eta 0:00:49
#    ---------------------------------------- 0.0/16.1 MB 330.3 kB/s eta 0:00:49
#    ---------------------------------------- 0.0/16.1 MB 330.3 kB/s eta 0:00:49
#    ---------------------------------------- 0.0/16.1 MB 330.3 kB/s eta 0:00:49
#    ---------------------------------------- 0.0/16.1 MB 122.9 kB/s eta 0:02:11
#    ---------------------------------------- 0.0/16.1 MB 122.9 kB/s eta 0:02:11
#    ---------------------------------------- 0.0/16.1 MB 122.9 kB/s eta 0:02:11
#    ---------------------------------------- 0.1/16.1 MB 131.3 kB/s eta 0:02:03
#    ---------------------------------------- 0.1/16.1 MB 131.3 kB/s eta 0:02:03
#    ---------------------------------------- 0.1/16.1 MB 131.3 kB/s eta 0:02:03
# ...

# %%
sql = 'SELECT * FROM airbnb_new_york_city_open_data_2019;'

# %%
db = connection.connect(host="127.0.0.1",database="infobyte new york city airbnb open data", user="root",password="Fortune_12012006",use_pure= True)

# %%
df= pd.read_sql(sql,db)
df
# Out:
# C:\Users\Laptop\AppData\Local\Temp\ipykernel_16132\3833876851.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(sql,db)
#         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 286  66451                        Fantastic Williamsburg Apt   325389
# 287  66718                  West Harlem Home Base - Eco-Apt.   136227
# ...

# %%
df.to_excel('C:/Users/Laptop/Documents/Oasis Infobyte dataset(worked on)/airbnb_new_york_city_open_data_2019.xlsx',index=False)
